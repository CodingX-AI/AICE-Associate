# %% [markdown]
# # AICE Associate 실전 모의고사
#
# ## 퇴사 여부 예측 (Attrition Prediction)
#
# 인사 분석 데이터를 읽어들여 데이터를 분석 및 전처리한 후 머신러닝과 딥러닝으로 직원의 퇴사 여부(**Attrition: Yes / No**)를 예측하고 결과를 분석하세요.
#
# ---
# ### 데이터 설명
# - Age: 연령
# - Attrition: 퇴사 여부 (Yes/No)
# - BusinessTravel: 출장 빈도
# - DailyRate: 일급
# - Department: 근무 부서
# - DistanceFromHome: 집과의 거리
# - Education: 교육 수준
# - EducationField: 전공
# - EmployeeCount: 직원 수
# - EmployeeNumber: 직원 고유 번호 (ID)
# - EnvironmentSatisfaction: 환경 만족도
# - Gender: 성별
# - JobInvolvement: 직무 참여도
# - JobLevel: 직무 수준
# - JobRole: 직무 역할
# - JobSatisfaction: 직무 만족도
# - MaritalStatus: 결혼 상태
# - MonthlyRate: 월급
# - NumCompaniesWorked: 이직한 회사의 수
# - Over18: 18세 이상 여부
# - OverTime: 야근 여부
# - PercentSalaryHike: 급여 인상률
# - PerformanceRating: 성과 등급
# - RelationshipSatisfaction: 관계 만족도
# - StandardHours: 표준 근무 시간
# - StockOptionLevel: 스톡옵션 수준
# - TotalWorkingYears: 총 경력 연수
# - WorkLifeBalance: 워라밸
# - YearsAtCompany: 현재 회사 근속 연수
# - YearsSinceLastPromotion: 마지막 승진 후 기간
#
# ---

# %% [markdown]
# ### 1. 라이브러리를 임포트하는 코드를 작성하고 실행하세요.
# ---
# - Pandas 라이브러리를 별칭 pd로 임포트하세요.
# - Seaborn 라이브러리를 별칭 sns로 임포트하세요.
#     - 설치되어 있지 않으면 설치해서 임포트하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 다음 문항을 풀기 전에 아래의 코드를 실행하세요.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc("font", family="NanumGothicCoding")

# %% [markdown]
# ### 2. 모델링을 위해 분석 및 처리할 데이터 파일을 읽어오려고 합니다.
# ---
# pandas 함수로 데이터 파일을 읽고 데이터프레임 변수명 HR에 할당하는 코드를 작성하세요.
# - HR_Employee_Attrition.csv 파일을 읽어 HR에 할당하세요.
# - 출력된 데이터프레임의 정보와 일치하지 않는 내용을 '답안02' 변수에 저장하세요. (예: 답안02=1)
#     1. 총 데이터 행(row)의 개수는 1,470개이다.
#     2. Age(연령)의 중앙값은 36이다.
#     3. Attrition(퇴사 여부) 클래스 중 가장 많은 데이터는 'Yes'로, 총 1,233개 존재한다.
#     4. JobSatisfaction 컬럼에는 결측치가 존재한다.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 3. 직무 역할(JobRole)에 따라 월급(MonthlyRate)의 평균 분포를 비교해 보고자 합니다.
# ---
# 아래 가이드를 따라 barplot을 시각화하세요.
# - 대상 데이터프레임: HR
# - Seaborn의 barplot 활용하세요.
#     - 그래프의 크기는 `figsize=(20,5)`로 설정하세요.
#     - x: JobRole, y: MonthlyRate
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 4. 직무 역할(JobRole)별로 직무 만족도(JobSatisfaction)의 평균을 구하세요.
# ---
# - 대상 데이터프레임: HR
# - groupby를 사용하여 제시한 조건에 대한 통계를 구하세요.
# - 출력된 결과를 보고 해석한 것으로 옳지 않은 선택지를 아래에서 골라 "답안04" 변수에 저장하세요.(예: 답안04=1)
#     1. Healthcare Representative의 직무 만족도 평균이 가장 높다.
#     2. 세일즈(Sales)와 관련된 직무를 가지는 사람들의 직무 만족도는 항상 2.7 이상이다.
#     3. 모든 직무 역할의 직무 만족도 평균은 2.5 이상이다.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 5. 야근 여부(OverTime)에 따른 퇴사 여부(Attrition)의 분포를 확인해보려고 합니다.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: HR
# - Seaborn의 countplot 활용하세요.
# - 출력된 그래프와 다른 해석을 하는 선택지를 "답안05" 변수에 저장하세요. (예: 답안05=1)
#     1. 퇴사하지 않은 직원들 중에서는 야근을 하지 않는 경우가 훨씬 많다.
#     2. 퇴사한 직원은 총 200명 이하이다.
#     3. 전체적으로 퇴사자는 비퇴사자보다 수가 적다.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 6. 범주형 변수의 값을 수치형으로 변환하세요.
# ---
# 아래 코드는 범주형 변수인 Attrition과 OverTime 컬럼의 값을 Yes는 1, No는 0으로 변환하기 위한 코드입니다.\
# 주어진 코드를 확인한 뒤, < blank 1 > 과 < blank 2 > 부분을 채워 코드를 완성하고 실행하세요.
# 주어진 조건을 활용하세요.
# - 대상 데이터프레임: HR
# - 주어진 컬럼 리스트(`cols`) 와 for 문을 활용하세요.
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 HR_enc 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.
cols = ['Attrition', 'OverTime']
HR_enc = HR.copy()

for col in cols:
    HR_enc[col] = HR_enc < blank 1 > . < blank 2 > ({'Yes': 1, 'No': 0})
    
HR_enc.head()

# %% [markdown]
# ### 7. MonthlyRate 컬럼을 활용하여 파생변수를 생성하세요.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: HR_enc
# - MonthlyRate 컬럼에 12를 곱하여 연봉 파생변수(YearlyRate)를 생성하세요.
# - 파생변수가 추가된 결과를 새로운 데이터프레임 변수명 HR_add 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 8. 불필요한 컬럼을 삭제하세요.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: HR_add
# - 제거할 컬럼: EmployeeCount, Over18, StandardHours, EmployeeNumber
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 HR_del 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 9. 수치형 변수들의 상관관계를 확인하세요.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: HR_del
# - seaborn을 사용하세요
#     - 문제에서 주어진 `cols2`컬럼들만을 사용하여 상관계수를 계산하고 heatmap을 그리세요.
#     - 그래프 안에 상관계수 수치를 표시하세요.
# - Attrition과 상관관계가 가장 높은 변수를 찾아 "답안09" 변수에 문자열 형태로 작성하세요. (예: 답안09='Attrition')
#     - (단, Attrition 자신은 제외)
# ---

# %%
# 여기에 답안코드를 작성하세요.
cols2 = ['Age', 'DistanceFromHome', 'EnvironmentSatisfaction', 'JobSatisfaction', 'MonthlyRate', 'TotalWorkingYears', 'Attrition']

# %% [markdown]
# ---

# %%
# 다음 문제를 풀기 전에, 아래 코드를 실행하여 나머지 범주형 변수들을 One-Hot Encoding 방식으로 변환하세요.
HR_del = pd.get_dummies(HR_del)

# %% [markdown]
# ### 10. 모델링 성능을 제대로 얻기 위해서 결측치 처리는 필수입니다.
# ---
#  아래 가이드를 따라 결측치를 처리하세요.
# - 대상 데이터프레임: HR_del
#     - 각 컬럼별 결측치 개수를 확인하는 코드를 작성하세요.
#     - JobSatisfaction 컬럼의 결측치는 중앙값으로 대체하세요.
#     - 나머지 컬럼의 결측치는 행 기준으로 삭제하세요.
#     - 결측치 처리가 반영된 결과를 새로운 데이터프레임 변수명 HR_null 에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 11. 훈련 데이터와 평가 데이터를 분리하세요
# ---
# 타겟변수를 y 변수로, 나머지 컬럼을 X로 할당한 후, 훈련 데이터셋과 평가 데이터셋으로 분리하세요.
#
#  - 대상 데이터프레임: HR_null
#  - 훈련과 평가 데이터셋 분리
#      - 훈련 데이터셋 label: y_train, 훈련 데이터셋 Feature: X_train
#      - 평가 데이터셋 label: y_test, 평가 데이터셋 Feature: X_test
#      - 훈련 데이터셋과 평가 데이터셋의 비율은 80:20
#      - random_state: 42
#      - 타겟변수의 클래스 비율이 두 데이터셋에 유사하게 유지되도록 옵션을 지정하세요.
#      - Scikit-learn의 train_test_split 함수를 활용하세요
#      - 데이터 분할 후 훈련 데이터의 개수를 "답안11" 변수에 저장하세요. (예시: 답안11=10000)
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 12. 현재의 데이터셋은 머신러닝에 바로 사용할 수 없는 형태입니다.
# ---
# 다음 가이드를 따라서 훈련 데이터셋과 평가 데이터셋에 스케일링을 수행하세요.
# - 최솟값을 0으로, 최댓값을 1로 만드는 스케일링을 수행하세요.
#     - sklearn.preprocessing 모듈의 스케일러 객체를 활용하세요.
#     - 훈련 데이터(X_train)에 대해 fit_transform()을 수행하세요.
#     - 평가 데이터(X_test)에 대해서는 transform()만 수행하세요.
#     - 스케일링이 적용된 훈련 데이터셋은 x_train, 평가 데이터셋은 x_test 변수에 할당하세요.
# - 스케일링 이후, np.max() 함수를 활용하여 x_train의 최댓값을 구한 뒤 "답안12" 변수에 정수 형태로 저장하세요. (예: 답안12=100)
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 13. 퇴사 여부를 예측하는 머신러닝 모델을 만들려고 합니다.
# ---
# 로지스틱 회귀(Logistic Regression)와 랜덤 포레스트(Random Forest)는 입력 변수의 패턴을 학습하여 범주형 타깃을 예측하는 데 활용되는 대표적인 지도학습 알고리즘입니다.
#
# 아래 가이드에 따라 두 가지 분류 모델을 생성하고 학습을 진행하세요.
#
#  - sklearn의 로지스틱 회귀(Logistic Regression)
#      - n_jobs: -1로 설정
#      - max_iter: 1000으로 설정
#      - random_state: 120로 설정
#      - 생성한 모델을 lr 변수에 저장하세요.
#  - sklearn의 랜덤 포레스트(Random Forest)
#      - 트리의 최대 깊이: 6으로 설정
#      - n_estimators: 50으로 설정
#      - random_state : 120로 설정
#      - 생성한 모델을 rfc 변수에 저장하세요.
#  - 위의 2개의 모델에 대해 fit을 활용해 모델을 학습해 주세요. 학습 시 최종 전처리된 훈련 데이터셋을 활용해 주세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 14. 13번에서 학습한 모델의 성능을 평가하려고 합니다.
# ---
# 앞에서 학습한 두 가지 모델의 성능을 비교해 봅시다.
# - 성능 평가는 최종 전처리된 평가 데이터셋을 활용하세요.
# - 각 모델을 활용해 평가 데이터에 대해 y값을 예측(predict)하고 각각 y_pred_lr, y_pred_rfc 변수에 저장하세요.
# - 각 모델 예측값에 대해 F1-score를 계산하고 성능을 비교하세요.
# - F1-score 기준으로 성능이 더 좋은 모델의 이름을 '답안14' 변수에 저장하세요.
# - 예) 답안14='LogisticRegression' 혹은 답안14='RandomForestClassifier'
# ---

# %%
# 여기에 답안코드를 작성하세요.

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)
# print(tf.config.list_physical_devices('CPU'))

# %% [markdown]
# ### 15. 퇴사 여부를 예측하는 딥러닝 모델을 만들려고 합니다.
# ---
# 아래 가이드에 따라 모델링하고 학습을 진행하세요.
# - Tensorflow framework를 사용하여 딥러닝 모델을 만드세요.
# - 아래의 설계된 모델을 구현하세요.
# - 손실함수는 'categorical_crossentropy'를 사용하고, 손실함수를 최적화하기 위한 알고리즘은 'adam'을 사용하세요.
# - 평가 데이터셋(x_test)을 딥러닝 모델의 검증 데이터셋으로서 사용하고, 각 에포크마다 검증 데이터셋을 'accuracy'로 평가하세요.
# - 하이퍼파라미터
#     - epochs: 50
#     - batch_size: 32
# - 각 에포크마다 loss와 metrics를 평가하기 위한 데이터로 전처리가 완료된 검증 데이터셋을 사용하세요.
# - EarlyStopping을 사용하여 val_loss를 기준으로 5회의 대기 후 성능이 향상되지 않으면 종료하도록 설정하세요.
# - ModelCheckpoint를 활용하여 최고 성능의 모델을 동일 폴더에 'best_model.h5'라는 이름으로 저장하세요.
# - 학습정보는 history 변수에 저장해 주세요.
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 이 코드를 실행한 후 답안코드를 작성하세요.
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# ### 16. 15번에서 저장한 딥러닝 모델을 불러와서 주어진 데이터로 시뮬레이션을 하려 합니다.
# ---
# 다음 가이드를 따라 시뮬레이션을 진행하세요.
# - tensorflow.keras.models의 load_model을 사용하여 'best_model.h5' 모델을 best_dl 변수로 불러옵니다.
# - 주어진 시뮬레이션 데이터에 대해 예측결과를 구하고 퇴사 여부를 '답안16' 변수에 저장하세요.
# - 예) 답안16='Yes' 또는 답안16='No'
# ---

# %%
simul = np.array([-0.30525801, -1.23420728, -0.90919718, 1.07889903, 0.27172652, 0.41176375, -0.94536071, 0.19875724, -0.42501186,  1.318421, -0.63697058,  0.75969449, -0.43448304, 1.20904946, 0.22589974, -0.66835717, 0.33130426, -0.48902297, -0.3786399, -0.42501186, -0.34862632, 2.09458426, -1.54966443, -0.21723492, -1.41307628, 1.56993121, -0.13630567, -0.83524371, 2.98578191, -0.68052062, -0.24799882, -0.32492357,  1.23244429, -1.23244429, -0.31883357, -0.18856181, -0.46892994, -0.25760737, -0.3368985, -0.24799882, -0.50770049, -0.49932931, 3.74596557, -0.54593968, 1.09695474, -0.68052062]).reshape(1, -1)

# %%
# 여기에 답안코드를 작성하세요.

# %% [markdown]
# 모든 문제를 다 푸셨습니다. 고생하셨습니다.
